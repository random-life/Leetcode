# %%
#!/usr/bin/env python
# Created by Bruce yuan on 18-1-22.
import requests
import os
import json
import time

class Config:
    """
    some config, such as your github page
    这里需要配置你自己的项目地址
    １．　本地仓库的的路径
    ２．　github中的仓库leetcode解法的路径
    """
    local_path = 'F:/Code/VScode/Leetcode/'
    # solution of leetcode
    github_leetcode_url = 'https://github.com/ligoudanaierya/Leetcode/blob/master/leetcode-algorithms/'
    # solution of pat,　暂时还没写
    github_pat_url = 'https://github.com/ligoudanaierya/Leetcode/blob/master/leetcode-algorithms/'
    leetcode_url = 'https://leetcode.com/problems/'

class Question:
    """
    this class used to store the inform of every question
    """

    def __init__(self, id_,
                 name, url,
                 lock, difficulty):
        self.id_ = id_
        self.title = name
        # the problem description url　问题描述页
        self.url = url
        self.lock = lock  # boolean，锁住了表示需要购买
        self.difficulty = difficulty
        # the solution url
        self.python = ''
        self.java = ''
        self.javascript = ''
        self.c_plus_plus = ''

    def __repr__(self):
        """
        没啥用，我为了调试方便写的
        :return:
        """
        return str(self.id_) + ' ' + str(self.title) + ' ' + str(self.url)

class TableInform:
    def __init__(self):
        # raw questions inform
        self.questions = []
        # this is table index
        self.table = []
        # this is the element of question
        self.table_item = {}
        self.locked = 0

    def get_leetcode_problems(self):
        """
        used to get leetcode inform
        :return:
        """
        # we should look the response data carefully to find law
        # return byte. content type is byte
        content = requests.get('https://leetcode.com/api/problems/algorithms/').content
        # get all problems
        self.questions = json.loads(content.decode('utf-8'))['stat_status_pairs']
        # print(self.questions)
        difficultys = ['Easy', 'Medium', 'Hard']
        for i in range(len(self.questions) - 1, -1, -1):
            question = self.questions[i]
            name = question['stat']['question__title']
            url = question['stat']['question__title_slug']
            id_ = str(question['stat']['frontend_question_id'])
            if int(id_) < 10:
                id_ = '00' + id_
            elif int(id_) < 100:
                id_ = '0' + id_
            lock = question['paid_only']
            if lock:
                self.locked += 1
            difficulty = difficultys[question['difficulty']['level'] - 1]
            url = Config.leetcode_url + url + '/description/'
            q = Question(id_, name, url, lock, difficulty)
            self.table.append(q.id_)
            self.table_item[q.id_] = q
        return self.table, self.table_item

    # create problems folders
    def __create_folder(self, oj_name):
        oj_algorithms = Config.local_path + '/' + oj_name + '-algorithms'
        if os.path.exists(oj_algorithms):
            print(oj_name, ' algorithms is already exits')
        else:
            print('creating {} algorithms....'.format(oj_name))
            os.mkdir(oj_algorithms)
        for item in self.table_item.values():
            question_folder_name = oj_algorithms + '/' + item.id_ + '_' + item.title.replace(' ','_').replace('?','')
            if not os.path.exists(question_folder_name):
                print(question_folder_name + 'is not exits, create it now....')
                os.mkdir(question_folder_name)

    def update_table(self, oj):
        # the complete inform should be update
        complete_info = CompleteInform()
        self.get_leetcode_problems()
        # the total problem nums
        complete_info.total = len(self.table)
        complete_info.lock = self.locked
        self.__create_folder(oj)
        oj_algorithms = Config.local_path + '/' + oj + '-algorithms'
        # 查看os.walk看具体返回的是什么东西
        for _, folders, _ in os.walk(oj_algorithms):
            for folder in folders:
                for _, _, files in os.walk(os.path.join(oj_algorithms, folder)):
                    # print(files)
                    if len(files) != 0:
                        complete_info.complete_num += 1
                    for item in files:
                        if item.endswith('.py'):
                            complete_info.solved['python'] += 1
                            folder_url = folder.replace(' ', "%20")
                            folder_url = os.path.join(folder_url, item).replace('\\', '/')
                            folder_url = os.path.join(Config.github_leetcode_url, folder_url)
                            self.table_item[folder[:3]].python = '[Python]({})'.format(folder_url)
                        elif item.endswith('.java'):
                            complete_info.solved['java'] += 1
                            folder_url = folder.replace(' ', "%20")
                            folder_url = os.path.join(folder_url, item).replace('\\', '/')
                            folder_url = os.path.join(Config.github_leetcode_url, folder_url)
                            self.table_item[folder[:3]].java = '[Java]({})'.format(folder_url)
                        elif item.endswith('.cpp'):
                            complete_info.solved['c++'] += 1
                            folder_url = folder.replace(' ', "%20")
                            folder_url = os.path.join(folder_url, item).replace('\\', '/')
                            print(folder_url)
                            folder_url = os.path.join(Config.github_leetcode_url, folder_url)
                            self.table_item[folder[:3]].c_plus_plus = '[C++]({})'.format(folder_url)
                        elif item.endswith('.js'):
                            complete_info.solved['javascript'] += 1
                            folder_url = folder.replace(' ', "%20")
                            folder_url = os.path.join(folder_url, item).replace('\\', '/')
                            folder_url = os.path.join(Config.github_leetcode_url, folder_url)
                            self.table_item[folder[:3]].javascript = '[JavaScript]({})'.format(folder_url)
        readme = Readme(complete_info.total, complete_info.complete_num, complete_info.lock, complete_info.solved)
        readme.create_leetcode_readme([self.table, self.table_item])
        print('-------the complete inform-------')
        print(complete_info.solved)

class CompleteInform:
    """
    this is statistic inform
    """

    def __init__(self):
        self.solved = {
            'python': 0,
            'c++': 0,
            'java': 0,
            'javascript': 0
        }
        self.complete_num = 0
        self.lock = 0
        self.total = 0

    def __repr__(self):
        return str(self.solved)

class Readme:
    """
    generate folder and markdown file
    update README.md when you finish one problem by some language
    """

    def __init__(self, total, solved, locked, others):
        """
        :param total: total problems nums
        :param solved: solved problem nums
        :param others: 暂时还没用，我想做扩展
        """
        self.total = total
        self.solved = solved
        self.others = others
        self.locked = locked
        self.time = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
        self.msg = '# Keep thinking, keep alive\n' \
                   'Until {}, I have solved **{}** / **{}** problems ' \
                   'while **{}** are still locked.' \
                   '\n\nCompletion statistic: ' \
                   '\n1. JavaScript: {javascript} ' \
                   '\n2. Python: {python}' \
                   '\n3. C++: {c++}' \
                   '\n4. Java: {java}' \
                   '\n\nNote: :lock: means you need to buy a book from LeetCode\n'.format(
                    self.time, self.solved, self.total, self.locked, **self.others)

    def create_leetcode_readme(self, table_instance):
        """
        create REAdME.md
        :return:
        """
        file_path = Config.local_path + '/README.md'
        # write some basic inform about leetcode
        with open(file_path, 'w') as f:
            f.write(self.msg)
            f.write('\n----------------\n')

        with open(file_path, 'a') as f:
            f.write('## LeetCode Solution Table\n')
            f.write('| ID | Title | Difficulty | JavaScript | Python | C++ | Java |\n')
            f.write('|:---:' * 7 + '|\n')
            table, table_item = table_instance
            for index in table:
                item = table_item[index]
                if item.lock:
                    _lock = ':lock:'
                else:
                    _lock = ''
                data = {
                    'id': item.id_,
                    'title': '[{}]({}) {}'.format(item.title, item.url, _lock),
                    'difficulty': item.difficulty,
                    'js': item.javascript if item.javascript else 'To Do',
                    'python': item.python if item.python else 'To Do',
                    'c++': item.c_plus_plus if item.c_plus_plus else 'To Do',
                    'java': item.java if item.java else 'To Do'
                }
                line = '|{id}|{title}|{difficulty}|{js}|{python}|{c++}|{java}|\n'.format(**data)
                f.write(line)
            print('README.md was created.....')

def main():
    table = TableInform()
    table.update_table('leetcode')

if __name__ == '__main__':
    main()
# Out:
# leetcode  algorithms is already exits
# F:/Code/VScode/Leetcode//leetcode-algorithms/785_Is_Graph_Bipartiteis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/786_K-th_Smallest_Prime_Fractionis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/787_Cheapest_Flights_Within_K_Stopsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/788_Rotated_Digitsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/789_Escape_The_Ghostsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/790_Domino_and_Tromino_Tilingis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/791_Custom_Sort_Stringis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/792_Number_of_Matching_Subsequencesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/793_Preimage_Size_of_Factorial_Zeroes_Functionis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/794_Valid_Tic-Tac-Toe_Stateis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/795_Number_of_Subarrays_with_Bounded_Maximumis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/796_Rotate_Stringis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/797_All_Paths_From_Source_to_Targetis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/798_Smallest_Rotation_with_Highest_Scoreis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/799_Champagne_Toweris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/705_Design_HashSetis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/706_Design_HashMapis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/800_Similar_RGB_Coloris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/801_Minimum_Swaps_To_Make_Sequences_Increasingis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/802_Find_Eventual_Safe_Statesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/803_Bricks_Falling_When_Hitis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/804_Unique_Morse_Code_Wordsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/805_Split_Array_With_Same_Averageis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/806_Number_of_Lines_To_Write_Stringis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/807_Max_Increase_to_Keep_City_Skylineis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/808_Soup_Servingsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/809_Expressive_Wordsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/810_Chalkboard_XOR_Gameis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/811_Subdomain_Visit_Countis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/812_Largest_Triangle_Areais not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/813_Largest_Sum_of_Averagesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/814_Binary_Tree_Pruningis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/815_Bus_Routesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/816_Ambiguous_Coordinatesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/817_Linked_List_Componentsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/818_Race_Caris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/819_Most_Common_Wordis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/707_Design_Linked_Listis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/820_Short_Encoding_of_Wordsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/821_Shortest_Distance_to_a_Characteris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/822_Card_Flipping_Gameis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/823_Binary_Trees_With_Factorsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/708_Insert_into_a_Cyclic_Sorted_Listis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/824_Goat_Latinis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/825_Friends_Of_Appropriate_Agesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/826_Most_Profit_Assigning_Workis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/827_Making_A_Large_Islandis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/828_Unique_Letter_Stringis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/829_Consecutive_Numbers_Sumis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/830_Positions_of_Large_Groupsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/831_Masking_Personal_Informationis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/641_Design_Circular_Dequeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/622_Design_Circular_Queueis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/832_Flipping_an_Imageis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/833_Find_And_Replace_in_Stringis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/834_Sum_of_Distances_in_Treeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/835_Image_Overlapis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/489_Robot_Room_Cleaneris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/836_Rectangle_Overlapis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/837_New_21_Gameis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/838_Push_Dominoesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/839_Similar_String_Groupsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/840_Magic_Squares_In_Gridis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/841_Keys_and_Roomsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/842_Split_Array_into_Fibonacci_Sequenceis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/843_Guess_the_Wordis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/844_Backspace_String_Compareis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/845_Longest_Mountain_in_Arrayis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/846_Hand_of_Straightsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/847_Shortest_Path_Visiting_All_Nodesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/848_Shifting_Lettersis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/849_Maximize_Distance_to_Closest_Personis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/850_Rectangle_Area_IIis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/851_Loud_and_Richis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/852_Peak_Index_in_a_Mountain_Arrayis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/853_Car_Fleetis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/854_K-Similar_Stringsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/855_Exam_Roomis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/856_Score_of_Parenthesesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms
not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/937_Reorder_Log_Filesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/938_Range_Sum_of_BSTis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/939_Minimum_Area_Rectangleis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/940_Distinct_Subsequences_IIis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/941_Valid_Mountain_Arrayis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/942_DI_String_Matchis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/943_Find_the_Shortest_Superstringis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/944_Delete_Columns_to_Make_Sortedis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/945_Minimum_Increment_to_Make_Array_Uniqueis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/946_Validate_Stack_Sequencesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/947_Most_Stones_Removed_with_Same_Row_or_Columnis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/948_Bag_of_Tokensis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/949_Largest_Time_for_Given_Digitsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/950_Reveal_Cards_In_Increasing_Orderis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/951_Flip_Equivalent_Binary_Treesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/952_Largest_Component_Size_by_Common_Factoris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/953_Verifying_an_Alien_Dictionaryis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/954_Array_of_Doubled_Pairsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/955_Delete_Columns_to_Make_Sorted_IIis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/956_Tallest_Billboardis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/957_Prison_Cells_After_N_Daysis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/958_Check_Completeness_of_a_Binary_Treeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/959_Regions_Cut_By_Slashesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/960_Delete_Columns_to_Make_Sorted_IIIis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/961_N-Repeated_Element_in_Size_2N_Arrayis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/962_Maximum_Width_Rampis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/963_Minimum_Area_Rectangle_IIis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/964_Least_Operators_to_Express_Numberis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/965_Univalued_Binary_Treeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/966_Vowel_Spellcheckeris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/967_Numbers_With_Same_Consecutive_Differencesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/968_Binary_Tree_Camerasis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/969_Pancake_Sortingis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/970_Powerful_Integersis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/971_Flip_Binary_Tree_To_Match_Preorder_Traversalis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/972_Equal_Rational_Numbersis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/509_Fibonacci_Numberis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/973_K_Closest_Points_to_Originis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/974_Subarray_Sums_Divisible_by_Kis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/975_Odd_Even_Jumpis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/976_Largest_Perimeter_Triangleis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/977_Squares_of_a_Sorted_Arrayis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/978_Longest_Turbulent_Subarrayis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/979_Distribute_Coins_in_Binary_Treeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/980_Unique_Paths_IIIis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/981_Time_Based_Key-Value_Storeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/982_Triples_with_Bitwise_AND_Equal_To_Zerois not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/983_Minimum_Cost_For_Ticketsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/984_String_Without_AAA_or_BBBis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/985_Sum_of_Even_Numbers_After_Queriesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/986_Interval_List_Intersectionsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/987_Vertical_Order_Traversal_of_a_Binary_Treeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/988_Smallest_String_Starting_From_Leafis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/989_Add_to_Array-Form_of_Integeris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/990_Satisfiability_of_Equality_Equationsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/991_Broken_Calculatoris not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/992_Subarrays_with_K_Different_Integersis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/993_Cousins_in_Binary_Treeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/994_Rotting_Orangesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/995_Minimum_Number_of_K_Consecutive_Bit_Flipsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/996_Number_of_Squareful_Arraysis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/997_Find_the_Town_Judgeis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/998_Maximum_Binary_Tree_IIis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/999_Available_Captures_for_Rookis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1000_Minimum_Cost_to_Merge_Stonesis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1001_Grid_Illuminationis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1002_Find_Common_Charactersis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1003_Check_If_Word_Is_Valid_After_Substitutionsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1004_Max_Consecutive_Ones_IIIis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1005_Maximize_Sum_Of_Array_After_K_Negationsis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1006_Clumsy_Factorialis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1007_Minimum_Domino_Rotations_For_Equal_Rowis not exits, create it now....
# F:/Code/VScode/Leetcode//leetcode-algorithms/1008_Construct_Binary_Search_Tree_from_Preorder_Traversalis not exits, create it now....
# README.md was created.....
# -------the complete inform-------
# {'python': 0, 'c++': 0, 'java': 0, 'javascript': 0}
